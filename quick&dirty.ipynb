# %%
import pandas as pd
import numpy as np
from scipy.stats import randint
import seaborn as sns # used for plot interactive graph. 
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
combined_df = pd.read_csv('combined_csvs/combined_vg_sales_summary.csv')

# %%
combined_df.head()
# Out:
#    Rank                           Name                      basename  \
# 0     1                     Wii Sports                    wii-sports
# 1     2              Super Mario Bros.              super-mario-bros
# 2     3                 Mario Kart Wii                mario-kart-wii
# 3     4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4     5              Wii Sports Resort             wii-sports-resort
#
#       Genre  Year ESRB_Rating Platform         Publisher         Developer  \
# 0    Sports  2006           E      Wii          Nintendo      Nintendo EAD
# 1  Platform  1985         NaN      NES          Nintendo      Nintendo EAD
# 2    Racing  2008           E      Wii          Nintendo      Nintendo EAD
# 3   Shooter  2017         NaN       PC  PUBG Corporation  PUBG Corporation
# 4    Sports  2009           E      Wii          Nintendo      Nintendo EAD
#
#    Critic_Score  User_Score  NA_Sales  PAL_Sales  JP_Sales  Other_Sales  \
# ...

# %%
shit = combined_df[["Rank", "Name", "Year", "Critic_Score", "Global_Total"]]
shit
# Out:
#         Rank                                               Name  Year  \
# 0          1                                         Wii Sports  2006
# 1          2                                  Super Mario Bros.  1985
# 2          3                                     Mario Kart Wii  2008
# 3          4                      PlayerUnknown's Battlegrounds  2017
# 4          5                                  Wii Sports Resort  2009
# ...      ...                                                ...   ...
# 18854  19858  FirePower for Microsoft Combat Flight Simulator 3  2004
# 18855  19859                         Tom Clancy's Splinter Cell  2003
# 18856  19860             Ashita no Joe 2: The Anime Super Remix  2002
# 18857  19861               Tokyo Yamanote Boys for V: Main Disc  2017
# 18858  19862             NadePro!! Kisama no Seiyuu Yatte Miro!  2009
#
#        Critic_Score  Global_Total
# 0               7.7         82.86
# 1              10.0         40.24
# ...

# %%
shit[pd.notnull(shit["Critic_Score"])]
shit.head(100)
# Out:
#     Rank                           Name  Year  Critic_Score  Global_Total
# 0      1                     Wii Sports  2006           7.7         82.86
# 1      2              Super Mario Bros.  1985          10.0         40.24
# 2      3                 Mario Kart Wii  2008           8.2         37.14
# 3      4  PlayerUnknown's Battlegrounds  2017           NaN         36.60
# 4      5              Wii Sports Resort  2009           8.0         33.09
# ..   ...                            ...   ...           ...           ...
# 95    96                 Gran Turismo 2  1999           9.2          9.37
# 96    97                      Wii Party  2010           7.0          9.32
# 97    98   Call of Duty: Black Ops IIII  2018           NaN          9.32
# 98    99                 Mario Party DS  2007           7.1          9.31
# 99   100            Donkey Kong Country  1994           9.0          9.30
#
# [100 rows x 5 columns]

# %%
X = cleaned["Global_Total"]
y = cleaned["Critic_Score"]
print(X.shape, y.shape)
# Out:
# (4426,) (4426,)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-f44724590846> in <module>
# ----> 1 classifier.fit(X_train, y_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1340             _dtype = [np.float64, np.float32]
#    1341
# -> 1342         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1343                                    order="C",
#    1344                                    accept_large_sparse=solver != 'liblinear')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ...
