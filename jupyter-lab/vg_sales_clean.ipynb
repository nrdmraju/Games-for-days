# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# pwd

# %%
# Read video game sales data scrapped from https://www.vgchartz.com/gamedb/
file = '../raw_data/vgsales-12-4-2019.csv'
df = pd.read_csv(file)
df
# Out:
#         Rank                           Name                      basename  \
# 0          1                     Wii Sports                    wii-sports
# 1          2              Super Mario Bros.              super-mario-bros
# 2          3                 Mario Kart Wii                mario-kart-wii
# 3          4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4          5              Wii Sports Resort             wii-sports-resort
# ...      ...                            ...                           ...
# 55787  55788                    Indivisible                   indivisible
# 55788  55789                     Lost Ember                    lost-amber
# 55789  55790                     Lost Ember                    lost-amber
# 55790  55791                     Lost Ember                    lost-amber
# 55791  55792                     Falcon Age                    falcon-age
#
#                   Genre ESRB_Rating Platform         Publisher  \
# ...

# %%
#  view of the range of the video game critic scores
# df['Vgchartzscore'].value_counts()

# %%
# fill NaN values in the Total_Shipped and Global Sales columns to 0 - so we can add these values in next step
df['Total_Shipped'].fillna(0, inplace=True)
df['Global_Sales'].fillna(0, inplace=True)

# %%
# total shipped and total sales are measured in the same units (per million units sold. it is not a currency value)
# create new total column so the video game sales data(to have less 0 values in each row)
# this was done so there is more sales data we can anaylyze 

df['Global_Total'] = df['Total_Shipped']+df['Global_Sales']

# %%
# create view of the non null values in the new Global_Total column to make sure previous worked

#df[df['Total_Shipped'].notnull()]
#df[df['Global_Sales'].notnull()]
df[df['Global_Total'].notnull()]
# Out:
#         Rank                           Name                      basename  \
# 0          1                     Wii Sports                    wii-sports
# 1          2              Super Mario Bros.              super-mario-bros
# 2          3                 Mario Kart Wii                mario-kart-wii
# 3          4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4          5              Wii Sports Resort             wii-sports-resort
# ...      ...                            ...                           ...
# 55787  55788                    Indivisible                   indivisible
# 55788  55789                     Lost Ember                    lost-amber
# 55789  55790                     Lost Ember                    lost-amber
# 55790  55791                     Lost Ember                    lost-amber
# 55791  55792                     Falcon Age                    falcon-age
#
#                   Genre ESRB_Rating Platform         Publisher  \
# ...

# %%
# identify rows in the dataframe where Global_Total is equal zero, rows we will need to drop
series = df[df['Global_Total']==0].index
series
# Out:
# Int64Index([19862, 19863, 19864, 19865, 19866, 19867, 19868, 19869, 19870,
#             19871,
#             ...
#             55782, 55783, 55784, 55785, 55786, 55787, 55788, 55789, 55790,
#             55791],
#            dtype='int64', length=35930)

# %%
# df = df.dropna(axis=0, subset=['Year','NA_Sales','PAL_Sales','JP_Sales'])
# df = df.dropna(axis=0, subset=['Total_Shipped'])

# %%
# drop the rows where Global Tatal is equal to zero and create new dataframe
clean_df = df.drop(df.index[series])
clean_df
# Out:
#         Rank                                               Name  \
# 0          1                                         Wii Sports
# 1          2                                  Super Mario Bros.
# 2          3                                     Mario Kart Wii
# 3          4                      PlayerUnknown's Battlegrounds
# 4          5                                  Wii Sports Resort
# ...      ...                                                ...
# 19857  19858  FirePower for Microsoft Combat Flight Simulator 3
# 19858  19859                         Tom Clancy's Splinter Cell
# 19859  19860             Ashita no Joe 2: The Anime Super Remix
# 19860  19861               Tokyo Yamanote Boys for V: Main Disc
# 19861  19862             NadePro!! Kisama no Seiyuu Yatte Miro!
#
#                                                 basename       Genre  \
# 0                                             wii-sports      Sports
# ...

# %%
# get overview of clean_df
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19862 entries, 0 to 19861
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            19862 non-null  int64
#  1   Name            19862 non-null  object
#  2   basename        19862 non-null  object
#  3   Genre           19862 non-null  object
#  4   ESRB_Rating     13925 non-null  object
#  5   Platform        19862 non-null  object
#  6   Publisher       19862 non-null  object
#  7   Developer       19860 non-null  object
#  8   VGChartz_Score  0 non-null      float64
#  9   Critic_Score    4706 non-null   float64
#  10  User_Score      238 non-null    float64
#  11  Total_Shipped   19862 non-null  float64
#  12  Global_Sales    19862 non-null  float64
#  13  NA_Sales        12777 non-null  float64
#  14  PAL_Sales       12125 non-null  float64
#  15  JP_Sales        6791 non-null   float64
#  16  Other_Sales     14510 non-null  float64
# ...

# %%
# clean_df['Vgchartzscore'].value_counts()
clean_df[:25]
# Out:
#     Rank                                          Name  \
# 0      1                                    Wii Sports
# 1      2                             Super Mario Bros.
# 2      3                                Mario Kart Wii
# 3      4                 PlayerUnknown's Battlegrounds
# 4      5                             Wii Sports Resort
# 5      6            Pokemon Red / Green / Blue Version
# 6      7                         New Super Mario Bros.
# 7      8                                        Tetris
# 8      9                     New Super Mario Bros. Wii
# 9     10                                     Minecraft
# 10    11                                     Duck Hunt
# 11    12                                      Wii Play
# 12    13                            Kinect Adventures!
# 13    14                                    Nintendogs
# 14    15                                 Mario Kart DS
# 15    16                 Pokemon Gold / Silver Version
# ...

# %%
#  save new dataframe to csv
clean_df.to_csv('../clean_csv_files/vg_sales_no_summary.csv', index=False)

# %%
##  divide the clean df into rows of 1000 to eventually run multiple scrapes at once
##  create new dataframes with 1000 rows each that Neil will evaluate
# neil_1 = clean_df[:1000]
# neil_2 = clean_df[1000:2000]
# neil_3 = clean_df[2000:3000]
# neil_4 = clean_df[3000:4000]
# neil_5 = clean_df[4000:5000]
# neil_6 = clean_df[6000:7000]
# neil_7 = clean_df[7000:8000]

# %%
## convert dataframes to csv files for Neil to read and scrape with scrape.py file
# neil_1.to_csv('../csv_files_for_scrape_script/neil_1.csv', index=False)
# neil_2.to_csv('../csv_files_for_scrape_script/neil_2.csv', index=False)
# neil_3.to_csv('../csv_files_for_scrape_script/neil_3.csv', index=False)
# neil_4.to_csv('../csv_files_for_scrape_script/neil_4.csv', index=False)
# neil_5.to_csv('../csv_files_for_scrape_script/neil_5.csv', index=False)
# neil_6.to_csv('../csv_files_for_scrape_script/neil_6.csv', index=False)
# neil_7.to_csv('../csv_files_for_scrape_script/neil_7.csv', index=False)

# %%
## create new dataframes with 1000 rows that Elijah will evaluate
# elijah_8 = clean_df[8000:9000]
# elijah_9 = clean_df[9000:10000]
# elijah_10 = clean_df[10000:11000]
# elijah_11 = clean_df[11000:12000]
# elijah_12 = clean_df[12000:13000]
# elijah_13 = clean_df[13000:14000]
# elijah_14 = clean_df[14000:15000]

# %%
## convert dataframes to csv files for Elijah to read and scrape with scrape.py file 
# elijah_8.to_csv('../csv_files_for_scrape_script/elijah_8.csv', index=False)
# elijah_9.to_csv('../csv_files_for_scrape_script/elijah_9.csv', index=False)
# elijah_10.to_csv('../csv_files_for_scrape_script/elijah_10.csv', index=False)
# elijah_11.to_csv('../csv_files_for_scrape_script/elijah_11.csv', index=False)
# elijah_12.to_csv('../csv_files_for_scrape_script/elijah_12.csv', index=False)
# elijah_13.to_csv('../csv_files_for_scrape_script/elijah_13.csv', index=False)
# elijah_14.to_csv('../csv_files_for_scrape_script/elijah_14.csv', index=False)

# %%
## create new dataframes with 1000 rows that Alvaro will evaluate
# alvaro_15 = clean_df[15000:16000]
# alvaro_16 = clean_df[16000:17000]
# alvaro_17 = clean_df[17000:18000]
# alvaro_18 = clean_df[18000:19000]
# alvaro_19 = clean_df[19000:20000]
# alvaro_20 = clean_df[20000:]

# %%
## convert dataframes to csv files for Alvaro to read and scrape with scrape.py file 
# alvaro_15.to_csv('../csv_files_for_scrape_script/alvaro_15.csv', index=False)
# alvaro_16.to_csv('../csv_files_for_scrape_script/alvaro_16.csv', index=False)
# alvaro_17.to_csv('../csv_files_for_scrape_script/alvaro_17.csv', index=False)
# alvaro_18.to_csv('../csv_files_for_scrape_script/alvaro_18.csv', index=False)
# alvaro_19.to_csv('../csv_files_for_scrape_script/alvaro_19.csv', index=False)
# alvaro_20.to_csv('../csv_files_for_scrape_script/alvaro_20.csv', index=False)

# %%
## create a test csv file to read and run the scrape.py file
test_df = clean_df[:25]
test_df.to_csv('../csv_files_for_scrape_script/test_df.csv', index=False)
