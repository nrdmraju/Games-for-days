# %%
# Importing required libraries 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
  
# Read the dataset 
df = pd.read_csv('clean_csv_files/vg_sales_no_summary.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19862 entries, 0 to 19861
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            19862 non-null  int64
#  1   Name            19862 non-null  object
#  2   basename        19862 non-null  object
#  3   Genre           19862 non-null  object
#  4   ESRB_Rating     13925 non-null  object
#  5   Platform        19862 non-null  object
#  6   Publisher       19862 non-null  object
#  7   Developer       19860 non-null  object
#  8   VGChartz_Score  0 non-null      float64
#  9   Critic_Score    4738 non-null   float64
#  10  User_Score      238 non-null    float64
#  11  Total_Shipped   19862 non-null  float64
#  12  Global_Sales    19862 non-null  float64
#  13  NA_Sales        12777 non-null  float64
#  14  PAL_Sales       12125 non-null  float64
#  15  JP_Sales        6791 non-null   float64
#  16  Other_Sales     14510 non-null  float64
# ...

# %%
pwd
# Out:
# 'C:\\Users\\a_mcr\\Desktop\\Bootcamp\\Group_Projects\\gt-project3'

# %%
df = df.dropna(subset=['Year'])

# %%
df["Year"] = df["Year"].astype(int)

# %%
# df.drop(columns = ['VGChartz_Score'], inplace=True)
# consider dropping this column once we have all our data scraped from VGCHARTZ

# %%
# could consider getting ave of VGcartzscore, user_score, and critic score to help predict score of game
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19859 entries, 0 to 19861
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            19859 non-null  int64
#  1   Name            19859 non-null  object
#  2   basename        19859 non-null  object
#  3   Genre           19859 non-null  object
#  4   ESRB_Rating     13924 non-null  object
#  5   Platform        19859 non-null  object
#  6   Publisher       19859 non-null  object
#  7   Developer       19857 non-null  object
#  8   VGChartz_Score  0 non-null      float64
#  9   Critic_Score    4738 non-null   float64
#  10  User_Score      238 non-null    float64
#  11  Total_Shipped   19859 non-null  float64
#  12  Global_Sales    19859 non-null  float64
#  13  NA_Sales        12777 non-null  float64
#  14  PAL_Sales       12123 non-null  float64
#  15  JP_Sales        6790 non-null   float64
#  16  Other_Sales     14507 non-null  float64
# ...

# %%
df.head(100)
# Out:
#     Rank                           Name                      basename  \
# 0      1                     Wii Sports                    wii-sports
# 1      2              Super Mario Bros.              super-mario-bros
# 2      3                 Mario Kart Wii                mario-kart-wii
# 3      4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4      5              Wii Sports Resort             wii-sports-resort
# ..   ...                            ...                           ...
# 95    96                 Gran Turismo 2                gran-turismo-2
# 96    97                      Wii Party                     wii-party
# 97    98   Call of Duty: Black Ops IIII   call-of-duty-black-ops-iiii
# 98    99                 Mario Party DS                mario-party-ds
# 99   100            Donkey Kong Country           donkey-kong-country
#
#        Genre ESRB_Rating Platform                    Publisher  \
# ...

# %%
df.to_csv('clean_csv_files/vg_sales_no_summary2.csv')
