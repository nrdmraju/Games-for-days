# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %%
quick_dirty = pd.read_csv('../combined_csvs/combined_vg_sales_summary.csv')
quick_dirty.head()
# Out:
#    Rank                           Name                      basename  \
# 0     1                     Wii Sports                    wii-sports
# 1     2              Super Mario Bros.              super-mario-bros
# 2     3                 Mario Kart Wii                mario-kart-wii
# 3     4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4     5              Wii Sports Resort             wii-sports-resort
#
#       Genre  Year ESRB_Rating Platform         Publisher         Developer  \
# 0    Sports  2006           E      Wii          Nintendo      Nintendo EAD
# 1  Platform  1985         NaN      NES          Nintendo      Nintendo EAD
# 2    Racing  2008           E      Wii          Nintendo      Nintendo EAD
# 3   Shooter  2017         NaN       PC  PUBG Corporation  PUBG Corporation
# 4    Sports  2009           E      Wii          Nintendo      Nintendo EAD
#
#    Critic_Score  User_Score  NA_Sales  PAL_Sales  JP_Sales  Other_Sales  \
# ...

# %%
# quick_dirty.dropna(subset=['Year', 'Global_Total', 'Critic_Score'])
# quick_dirty_2 = quick_dirty[['Name', 'Year','Critic_SCore','Global_Sales']].copy()
# quick_dirty_2
df_new = quick_dirty[['Rank','Name','Year','Critic_Score','Global_Total']].copy()
df_new
# Out:
#         Rank                                               Name  Year  \
# 0          1                                         Wii Sports  2006
# 1          2                                  Super Mario Bros.  1985
# 2          3                                     Mario Kart Wii  2008
# 3          4                      PlayerUnknown's Battlegrounds  2017
# 4          5                                  Wii Sports Resort  2009
# ...      ...                                                ...   ...
# 18854  19858  FirePower for Microsoft Combat Flight Simulator 3  2004
# 18855  19859                         Tom Clancy's Splinter Cell  2003
# 18856  19860             Ashita no Joe 2: The Anime Super Remix  2002
# 18857  19861               Tokyo Yamanote Boys for V: Main Disc  2017
# 18858  19862             NadePro!! Kisama no Seiyuu Yatte Miro!  2009
#
#        Critic_Score  Global_Total
# 0               7.7         82.86
# 1              10.0         40.24
# ...

# %%
poop_df = df_new.dropna(subset=['Year','Rank','Critic_Score','Global_Total'])
poop_df
# Out:
#         Rank                                Name  Year  Critic_Score  \
# 0          1                          Wii Sports  2006           7.7
# 1          2                   Super Mario Bros.  1985          10.0
# 2          3                      Mario Kart Wii  2008           8.2
# 4          5                   Wii Sports Resort  2009           8.0
# 5          6  Pokemon Red / Green / Blue Version  1998           9.4
# ...      ...                                 ...   ...           ...
# 18789  19793                        Call of Duty  2003           7.0
# 18791  19795                      Battle B-Daman  2006           6.0
# 18797  19801                          Dr. Sudoku  2006           6.7
# 18809  19813           Dawn of Discovery: Venice  2010           7.0
# 18813  19817            bit Generations: Dialhex  2006           7.0
#
#        Global_Total
# 0             82.86
# 1             40.24
# 2             37.14
# 4             33.09
# 5             31.38
# ...

# %%
poop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4426 entries, 0 to 18813
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          4426 non-null   int64
#  1   Name          4426 non-null   object
#  2   Year          4426 non-null   int64
#  3   Critic_Score  4426 non-null   float64
#  4   Global_Total  4426 non-null   float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 207.5+ KB

# %%
# Assign X (data) and y (target)
X = poop_df.drop(["Name","Global_Total","Year"], axis=1)
y = poop_df["Global_Total"]
print(X.shape, y.shape)
# Out:
# (4426, 2) (4426,)

# %%
print(y)
# Out:
# 0        82.86
# 1        40.24
# 2        37.14
# 4        33.09
# 5        31.38
#          ...
# 18789     0.01
# 18791     0.01
# 18797     0.01
# 18809     0.01
# 18813     0.01
# Name: Global_Total, Length: 4426, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X, y)

rf.score(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-7ff077c4c6f7> in <module>
#       1 rf = RandomForestClassifier(n_estimators=200)
# ----> 2 rf = rf.fit(X, y)
#       3
#       4 rf.score(X, y)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     328         self.n_outputs_ = y.shape[1]
#     329
# --> 330         y, expanded_class_weight = self._validate_y_class_weight(y)
#     331
#     332         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _validate_y_class_weight(self, y)
#     556
#     557     def _validate_y_class_weight(self, y):
# --> 558         check_classification_targets(y)
#     559
#     560         y = np.copy(y)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
# ...

# %%
importances = rf.feature_importances_
importances

# %%
sorted(zip(rf.feature_importances_, iris.feature_names), reverse=True)

# %%
# from sklearn.linear_model import LogisticRegression
# classifier = LogisticRegression()
# classifier

# %%
# classifier.fit(X_train, y_train)

# %%
# print(f"Training Data Score: {classifier.score(X_train, y_train)}")
# print(f"Testing Data Score: {classifier.score(X_test, y_test)}")

# %%
# pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
